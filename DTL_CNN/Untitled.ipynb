# %%
import numpy as np
import pandas as pd
pair_df=pd.read_csv("data/matching_symptoms.csv")
pair_df
# Out:
#    Symptom Codes        V1        V2            V3        V4        V5  \
# 0     C0006271_A  0.052774 -0.021925  1.070000e-16  0.019890  0.026169
# 1     C0006271_P -0.052774  0.021925 -1.070000e-16 -0.019890 -0.026169
# 2     C0231528_A  3.220141  3.686593  4.440000e-16  1.775746 -1.828666
# 3     C0231528_P -3.220141 -3.686593 -4.440000e-16 -1.775746  1.828666
# 4     C0521839_A  0.046846 -0.024969  6.250000e-17  0.012544  0.004106
# ..           ...       ...       ...           ...       ...       ...
# 91    C1276802_P -0.232579  0.099678 -7.700000e-16 -0.048714  0.019629
# 92    C0391853_A  0.000015 -0.000019  6.700000e-18  0.000025 -0.000006
# 93    C0391853_P -0.000015  0.000019 -6.700000e-18 -0.000025  0.000006
# 94    C0042963_A  3.541791  3.600898 -2.890000e-15  0.691601  0.706918
# 95    C0042963_P -3.541791 -3.600898  2.890000e-15 -0.691601 -0.706918
#
#           V6        V7        V8        V9  ...      V491      V492      V493  \
# ...
